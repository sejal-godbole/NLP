# %% [markdown]
# <a href="https://colab.research.google.com/github/sejal-godbole/NLP/blob/main/NLP_Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use WordNet to identify semantic relationships such as synonymy, antonymy, and hypernymy in text data.

# %% [markdown]
# Install Required Library

# %%
pip install nltk

# %% [markdown]
# Download WordNet Dataset

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# Import WordNet

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# Get Meaning of a Word (Synsets)

# %%
word = "happy"
synsets = wn.synsets(word)

print(synsets)
# Out:
# [Synset('happy.a.01'), Synset('felicitous.s.02'), Synset('glad.s.02'), Synset('happy.s.04')]

# %% [markdown]
# Find Synonyms

# %%
word = "happy"

synonyms = set()

for syn in wn.synsets(word):
    for lemma in syn.lemmas():
        synonyms.add(lemma.name())

print("Synonyms:", synonyms)
# Out:
# Synonyms: {'felicitous', 'well-chosen', 'glad', 'happy'}

# %% [markdown]
# Find Antonyms

# %%
word = "happy"

antonyms = set()

for syn in wn.synsets(word):
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print("Antonyms:", antonyms)
# Out:
# Antonyms: {'unhappy'}

# %% [markdown]
# Find Hypernyms

# %%
word = "dog"

hypernyms = set()

for syn in wn.synsets(word):
    for hyper in syn.hypernyms():
        hypernyms.add(hyper.name())

print("Hypernyms:", hypernyms)
# Out:
# Hypernyms: {'support.n.10', 'sausage.n.01', 'canine.n.02', 'chap.n.01', 'pursue.v.02', 'villain.n.01', 'unpleasant_woman.n.01', 'catch.n.06', 'domestic_animal.n.01'}

# %% [markdown]
# Find Hyponyms

# %%
word = "animal"

hyponyms = set()

for syn in wn.synsets(word):
    for hypo in syn.hyponyms():
        hyponyms.add(hypo.name())

print("Hyponyms:", hyponyms)
# Out:
# Hyponyms: {'hexapod.n.01', 'stunt.n.02', 'stayer.n.01', 'pest.n.04', 'male.n.01', 'acrodont.n.01', 'mutant.n.02', 'creepy-crawly.n.01', 'critter.n.01', 'captive.n.02', 'domestic_animal.n.01', 'feeder.n.06', 'young.n.01', 'homeotherm.n.01', 'thoroughbred.n.03', 'biped.n.01', 'prey.n.02', 'peeper.n.03', 'pleurodont.n.01', 'game.n.04', 'adult.n.02', 'work_animal.n.01', 'range_animal.n.01', 'zooplankton.n.01', 'survivor.n.03', 'mate.n.03', 'darter.n.02', 'embryo.n.02', 'female.n.01', 'insectivore.n.02', 'racer.n.03', 'molter.n.01', 'pet.n.01', 'omnivore.n.02', 'metazoan.n.01', 'varmint.n.02', 'invertebrate.n.01', 'larva.n.01', 'marine_animal.n.01', 'chordate.n.01', 'migrator.n.02', 'herbivore.n.01', 'scavenger.n.03', 'predator.n.02', 'fictional_animal.n.01', 'giant.n.01', 'poikilotherm.n.01'}
