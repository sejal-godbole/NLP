# %%
# !pip install transformers sentencepiece torch
# Out:
# Collecting transformers
#   Downloading transformers-5.2.0-py3-none-any.whl.metadata (32 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting torch
#   Downloading torch-2.10.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Using cached huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer-slim in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\asus\anaconda3\lib\site-packages (from torch) (4.11.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\asus\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\lib\site-packages (from torch) (75.1.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.27.0)
# Requirement already satisfied: shellingham in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\asus\anaconda3\lib\site-packages (from typer-slim->transformers) (8.1.7)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.2.0)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.2)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.7)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.14.0)
# Downloading transformers-5.2.0-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/10.4 MB 9.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.7/10.4 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 19.1 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 25.6 MB/s eta 0:00:00
# Downloading torch-2.10.0-cp312-cp312-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    --- ------------------------------------ 10.0/113.8 MB 47.8 MB/s eta 0:00:03
#    ------ --------------------------------- 19.4/113.8 MB 45.3 MB/s eta 0:00:03
#    -------- ------------------------------- 24.9/113.8 MB 38.5 MB/s eta 0:00:03
#    ------------ --------------------------- 35.9/113.8 MB 42.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 46.4/113.8 MB 43.4 MB/s eta 0:00:02
#    -------------------- ------------------- 58.2/113.8 MB 45.2 MB/s eta 0:00:02
#    ------------------------ --------------- 68.7/113.8 MB 46.1 MB/s eta 0:00:01
#    --------------------------- ------------ 77.1/113.8 MB 45.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 84.1/113.8 MB 44.0 MB/s eta 0:00:01
#    --------------------------------- ------ 94.6/113.8 MB 44.1 MB/s eta 0:00:01
#    ----------------------------------- --- 102.2/113.8 MB 43.5 MB/s eta 0:00:01
#    --------------------------------------  111.4/113.8 MB 43.4 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 42.9 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 42.9 MB/s eta 0:00:01
#    --------------------------------------- 113.8/113.8 MB 36.7 MB/s eta 0:00:00
# Using cached huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
# Installing collected packages: sympy, sentencepiece, safetensors, hf-xet, torch, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed hf-xet-1.2.0 huggingface-hub-1.4.1 safetensors-0.7.0 sentencepiece-0.2.1 sympy-1.14.0 tokenizers-0.22.2 torch-2.10.0 transformers-5.2.0

# %%
from transformers import MarianMTModel, MarianTokenizer

model_name = "Helsinki-NLP/opus-mt-en-hi"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# c:\Users\asus\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
def translate(text, model, tokenizer):
    inputs = tokenizer(text, return_tensors="pt", padding=True)
    translated = model.generate(**inputs)
    output = tokenizer.decode(translated[0], skip_special_tokens=True)
    return output
# Out:
# model.safetensors:   0%|          | 0.00/306M [00:00<?, ?B/s]

# %%
english_text = "Public health information should be accessible to everyone."
hindi_translation = translate(english_text, model, tokenizer)

print("English:", english_text)
print("Hindi:", hindi_translation)
# Out:
# English: Public health information should be accessible to everyone.
# Hindi: सार्वजनिक स्वास्थ्य जानकारी सभी को पहुँचनी चाहिए ।
