# %%
# !pip install transformers torch sentencepiece

# %%
from transformers import pipeline

sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="nlptown/bert-base-multilingual-uncased-sentiment"
)
# Out:
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
texts = [
    "यह फिल्म बहुत अच्छी थी।",          # Hindi
    "இந்த படம் மிகவும் அருமை.",        # Tamil
    "ఈ సినిమా చాలా బాగుంది.",          # Telugu
    "এই সিনেমাটি খুব ভালো ছিল।",      # Bengali
    "हा चित्रपट खूप छान होता."         # Marathi
]

results = sentiment_pipeline(texts)

for text, result in zip(texts, results):
    print(f"\nText: {text}")
    print("Predicted Sentiment Label:", result["label"])
    print("Confidence:", round(result["score"], 4))
# Out:
# Text: यह फिल्म बहुत अच्छी थी।
# Predicted Sentiment Label: 2 stars
# Confidence: 0.3955
#
# Text: இந்த படம் மிகவும் அருமை.
# Predicted Sentiment Label: 2 stars
# Confidence: 0.2454
#
# Text: ఈ సినిమా చాలా బాగుంది.
# Predicted Sentiment Label: 2 stars
# Confidence: 0.388
#
# Text: এই সিনেমাটি খুব ভালো ছিল।
# Predicted Sentiment Label: 4 stars
# Confidence: 0.3234
#
# Text: हा चित्रपट खूप छान होता.
# Predicted Sentiment Label: 1 star
# Confidence: 0.4974

# %%
def map_sentiment(label):
    stars = int(label[0])
    if stars <= 2:
        return "Negative"
    elif stars == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
for text, result in zip(texts, results):
    sentiment = map_sentiment(result["label"])
    print(f"\nText: {text}")
    print("Sentiment:", sentiment)
    print("Confidence:", round(result["score"], 4))
# Out:
# Text: यह फिल्म बहुत अच्छी थी।
# Sentiment: Negative
# Confidence: 0.3955
#
# Text: இந்த படம் மிகவும் அருமை.
# Sentiment: Negative
# Confidence: 0.2454
#
# Text: ఈ సినిమా చాలా బాగుంది.
# Sentiment: Negative
# Confidence: 0.388
#
# Text: এই সিনেমাটি খুব ভালো ছিল।
# Sentiment: Positive
# Confidence: 0.3234
#
# Text: हा चित्रपट खूप छान होता.
# Sentiment: Negative
# Confidence: 0.4974
